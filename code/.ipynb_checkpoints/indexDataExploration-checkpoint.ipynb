# %% [markdown]
# <center>
# <h1><font size=12>
# Weather Derivates </h1>
# <h1> ENSO Indices Exploration <br></h1>
#
# Developed by [Jesus Solano](mailto:ja.solano588@uniandes.edu.co) <br>
# 10 Julio 2018
# </center>

# %% [markdown]
# ### Indices data Analysis
#
# All datasets where downloaded from the Working group on Surface Pressure.
# [Link to full datasets](https://www.esrl.noaa.gov/psd/gcos_wgsp/Timeseries/)

# %% [markdown]
# ##### Southern Oscillation Index (SOI)

# %%
########  Southern Oscillation Index (SOI) ##############

# Download the update dataset.
import os
if not os.path.exists('../datasets/soi.dat'):
    ! wget https://crudata.uea.ac.uk/cru/data/soi/soi.dat -P ../datasets/

# Import modules to read and visualize.
import pandas as pd
import numpy as np
# %pylab inline

# Read dataset. We attempt to replace three spaces with two spaces to read correctly.
from io import StringIO
columnNames=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Anual']
soi=pd.read_csv(StringIO(''.join(l.replace('   ', '  ') for l in open('../datasets/soi.dat'))),sep='  ',header=None, names=columnNames, skipfooter=1  )

soi.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:16: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
#        Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec  \
# 1866 -0.62 -0.12 -0.62 -0.65  0.04 -0.82 -0.34  0.36 -0.18  0.07  1.10 -0.16
# 1867  0.09 -0.01 -0.09  0.83  0.50 -0.48  0.44  0.34  0.12 -0.56 -0.65 -0.89
# 1868 -0.16 -0.34 -1.56  0.30 -1.34 -2.20 -0.40 -1.41 -1.23 -1.24 -1.49  0.52
# 1869 -1.90 -0.26 -0.59  2.12  1.40  1.53  1.42  0.94  0.12  0.85  0.56  0.42
# 1870  1.06  0.18 -0.75  0.47 -0.11 -1.10  0.17  0.98 -0.00 -0.58 -0.86 -1.29
#
#       Anual
# 1866  -0.16
# 1867  -0.03
# 1868  -0.88
# 1869   0.55
# 1870  -0.15

# %%
soiMonth=soi.drop(columns='Anual')
soiMonth.head()
# Out:
#        Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# 1866 -0.62 -0.12 -0.62 -0.65  0.04 -0.82 -0.34  0.36 -0.18  0.07  1.10 -0.16
# 1867  0.09 -0.01 -0.09  0.83  0.50 -0.48  0.44  0.34  0.12 -0.56 -0.65 -0.89
# 1868 -0.16 -0.34 -1.56  0.30 -1.34 -2.20 -0.40 -1.41 -1.23 -1.24 -1.49  0.52
# 1869 -1.90 -0.26 -0.59  2.12  1.40  1.53  1.42  0.94  0.12  0.85  0.56  0.42
# 1870  1.06  0.18 -0.75  0.47 -0.11 -1.10  0.17  0.98 -0.00 -0.58 -0.86 -1.29

# %%
dates = pd.date_range('1866-01', periods=soiMonth.shape[0]*soiMonth.shape[1], freq='M')
dates
# Out:
# DatetimeIndex(['1866-01-31', '1866-02-28', '1866-03-31', '1866-04-30',
#                '1866-05-31', '1866-06-30', '1866-07-31', '1866-08-31',
#                '1866-09-30', '1866-10-31',
#                ...
#                '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30',
#                '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31',
#                '2017-11-30', '2017-12-31'],
#               dtype='datetime64[ns]', length=1824, freq='M')

# %%
soiMonth.plot(figsize=(20,10))

# %%
soiMonth.columns=range(1,13)

soiAllTime=soiMonth.stack()

soiAllTime.columns=range(1,13)
year=soiAllTime.index.get_level_values(0).values
month=soiAllTime.index.get_level_values(1).values

soiAllTime.index = pd.PeriodIndex(year=year,month=month,freq='M')

soiAllTime
# Out:
# 1866-01   -0.62
# 1866-02   -0.12
# 1866-03   -0.62
# 1866-04   -0.65
# 1866-05    0.04
# 1866-06   -0.82
# 1866-07   -0.34
# 1866-08    0.36
# 1866-09   -0.18
# 1866-10    0.07
# 1866-11    1.10
# 1866-12   -0.16
# 1867-01    0.09
# 1867-02   -0.01
# 1867-03   -0.09
# 1867-04    0.83
# 1867-05    0.50
# 1867-06   -0.48
# 1867-07    0.44
# 1867-08    0.34
# 1867-09    0.12
# 1867-10   -0.56
# 1867-11   -0.65
# 1867-12   -0.89
# 1868-01   -0.16
# 1868-02   -0.34
# 1868-03   -1.56
# 1868-04    0.30
# 1868-05   -1.34
# 1868-06   -2.20
#            ...
# 2015-07   -1.41
# 2015-08   -2.15
# 2015-09   -1.65
# 2015-10   -1.91
# 2015-11   -0.63
# 2015-12   -1.00
# 2016-01   -2.12
# 2016-02   -2.09
# 2016-03   -0.75
# 2016-04   -2.61
# 2016-05    0.22
# 2016-06    0.44
# 2016-07    0.45
# 2016-08    0.40
# 2016-09    1.28
# 2016-10   -0.66
# 2016-11   -0.23
# 2016-12    0.19
# 2017-01    0.08
# 2017-02   -0.33
# 2017-03    0.41
# 2017-04   -0.75
# 2017-05    0.23
# 2017-06   -1.39
# 2017-07    0.85
# 2017-08    0.17
# 2017-09    0.62
# 2017-10    0.75
# 2017-11    0.94
# 2017-12   -0.27
# Freq: M, Length: 1824, dtype: float64

# %%
soiAllTime.plot(title='SOI Index',figsize=(20,10))

# %%
soiMonth.plot(subplots=True,figsize=(20,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f6100dc94e0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f6100ea2898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f6100deae10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f610050b3c8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f6100524940>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f61004bfeb8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f61004dc470>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f61004f59e8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f610048cf60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f61004ab518>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f6100443a90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f6100461048>],
#       dtype=object)

# %%
soiTime = pd.Series(soiAllTime.iloc[-80:-5])
soiTime
# Out:
# 2011-05    0.46
# 2011-06   -0.04
# 2011-07    1.11
# 2011-08    0.07
# 2011-09    1.14
# 2011-10    0.91
# 2011-11    1.41
# 2011-12    2.45
# 2012-01    0.90
# 2012-02    0.22
# 2012-03    0.20
# 2012-04   -0.65
# 2012-05   -0.38
# 2012-06   -1.51
# 2012-07   -0.15
# 2012-08   -0.74
# 2012-09    0.22
# 2012-10    0.17
# 2012-11    0.33
# 2012-12   -0.77
# 2013-01   -0.10
# 2013-02   -0.47
# 2013-03    1.06
# 2013-04    0.01
# 2013-05    0.90
# 2013-06    1.45
# 2013-07    0.76
# 2013-08   -0.23
# 2013-09    0.41
# 2013-10   -0.34
#            ...
# 2015-02   -0.04
# 2015-03   -1.40
# 2015-04   -0.27
# 2015-05   -1.04
# 2015-06   -1.72
# 2015-07   -1.41
# 2015-08   -2.15
# 2015-09   -1.65
# 2015-10   -1.91
# 2015-11   -0.63
# 2015-12   -1.00
# 2016-01   -2.12
# 2016-02   -2.09
# 2016-03   -0.75
# 2016-04   -2.61
# 2016-05    0.22
# 2016-06    0.44
# 2016-07    0.45
# 2016-08    0.40
# 2016-09    1.28
# 2016-10   -0.66
# 2016-11   -0.23
# 2016-12    0.19
# 2017-01    0.08
# 2017-02   -0.33
# 2017-03    0.41
# 2017-04   -0.75
# 2017-05    0.23
# 2017-06   -1.39
# 2017-07    0.85
# Freq: M, Length: 75, dtype: float64

# %%
soiTime.plot(figsize=(20,10))

# %% [markdown]
# ##### North Atlantic Oscillation (NAO)

# %%
########  North Atlantic Oscillation (NAO) ##############

# Download the update dataset.
import os
if not os.path.exists('../datasets/nao.dat'):
    ! wget https://crudata.uea.ac.uk/cru/data/nao/nao.dat -P ../datasets/

# Import modules to read and visualize.
import pandas as pd
import numpy as np
# %pylab inline

# Read dataset. We attempt to replace three spaces with two spaces to read correctly.
from io import StringIO
columnNames=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Anual']
nao=pd.read_csv(StringIO(''.join(l.replace('   ', '  ') for l in open('../datasets/nao.dat'))),sep='  ',header=None,skiprows=[0,1,2,3,4], names=columnNames, skipfooter=1,  )

nao.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:16: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
#        Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec  \
# 1826 -3.05  4.87 -0.97  1.78 -1.20  0.83  1.89  2.72 -0.76  0.18 -2.41 -0.59
# 1827 -0.45 -3.72  1.83 -0.83  1.20 -0.07  2.02 -3.56 -0.07 -3.02 -1.42  2.70
# 1828  1.27  0.37 -0.18  0.04 -1.59 -1.33 -4.40 -2.54 -2.78  0.10 -2.57  3.04
# 1829 -2.48  0.32 -2.54  0.12  1.80 -0.10  0.33  0.77  0.78  0.71 -0.33 -0.43
# 1830 -2.33  1.20  3.58  3.08 -0.05 -0.85  3.19 -0.35  2.04  2.04  2.19 -3.13
#
#       Anual
# 1826   0.27
# 1827  -0.45
# 1828  -0.88
# 1829  -0.09
# 1830   0.88

# %%
naoMonth=nao.drop(columns='Anual')
naoMonth.head()
# Out:
#        Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# 1826 -3.05  4.87 -0.97  1.78 -1.20  0.83  1.89  2.72 -0.76  0.18 -2.41 -0.59
# 1827 -0.45 -3.72  1.83 -0.83  1.20 -0.07  2.02 -3.56 -0.07 -3.02 -1.42  2.70
# 1828  1.27  0.37 -0.18  0.04 -1.59 -1.33 -4.40 -2.54 -2.78  0.10 -2.57  3.04
# 1829 -2.48  0.32 -2.54  0.12  1.80 -0.10  0.33  0.77  0.78  0.71 -0.33 -0.43
# 1830 -2.33  1.20  3.58  3.08 -0.05 -0.85  3.19 -0.35  2.04  2.04  2.19 -3.13

# %%
datesNao = pd.date_range('1826-01', periods=naoMonth.shape[0]*naoMonth.shape[1], freq='M')
datesNao
# Out:
# DatetimeIndex(['1826-01-31', '1826-02-28', '1826-03-31', '1826-04-30',
#                '1826-05-31', '1826-06-30', '1826-07-31', '1826-08-31',
#                '1826-09-30', '1826-10-31',
#                ...
#                '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30',
#                '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31',
#                '2017-11-30', '2017-12-31'],
#               dtype='datetime64[ns]', length=2304, freq='M')

# %%
naoMonth.plot(figsize=(20,10))

# %%
naoMonth.columns=range(1,13)

naoAllTime=naoMonth.stack()

naoAllTime.columns=range(1,13)
year=naoAllTime.index.get_level_values(0).values
month=naoAllTime.index.get_level_values(1).values

naoAllTime.index = pd.PeriodIndex(year=year,month=month,freq='M')

naoAllTime
# Out:
# 1826-01   -3.05
# 1826-02    4.87
# 1826-03   -0.97
# 1826-04    1.78
# 1826-05   -1.20
# 1826-06    0.83
# 1826-07    1.89
# 1826-08    2.72
# 1826-09   -0.76
# 1826-10    0.18
# 1826-11   -2.41
# 1826-12   -0.59
# 1827-01   -0.45
# 1827-02   -3.72
# 1827-03    1.83
# 1827-04   -0.83
# 1827-05    1.20
# 1827-06   -0.07
# 1827-07    2.02
# 1827-08   -3.56
# 1827-09   -0.07
# 1827-10   -3.02
# 1827-11   -1.42
# 1827-12    2.70
# 1828-01    1.27
# 1828-02    0.37
# 1828-03   -0.18
# 1828-04    0.04
# 1828-05   -1.59
# 1828-06   -1.33
#            ...
# 2015-07   -2.16
# 2015-08    1.47
# 2015-09   -1.65
# 2015-10   -1.13
# 2015-11    3.54
# 2015-12    4.22
# 2016-01    1.17
# 2016-02    1.61
# 2016-03    0.33
# 2016-04   -2.06
# 2016-05   -0.83
# 2016-06   -1.27
# 2016-07    2.19
# 2016-08    2.14
# 2016-09    2.45
# 2016-10   -1.47
# 2016-11   -1.61
# 2016-12    2.10
# 2017-01    0.17
# 2017-02    1.38
# 2017-03    1.05
# 2017-04    1.50
# 2017-05    0.38
# 2017-06   -0.55
# 2017-07    0.10
# 2017-08   -0.04
# 2017-09    1.42
# 2017-10    1.36
# 2017-11   -0.90
# 2017-12    1.00
# Freq: M, Length: 2304, dtype: float64

# %%
naoAllTime.plot(title='NAO Index',figsize=(20,10))

# %%
naoMonth.plot(subplots=True,figsize=(20,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f60f96c06a0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f60f96df630>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f60f9677ba8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f60f9694160>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f60f962c6d8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f60f9644c50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f60f9663208>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f60f95fb780>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f60f9614cf8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f60f95b12b0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f60f95c8828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f60f95deda0>],
#       dtype=object)

# %%
naoTime = pd.Series(naoAllTime.iloc[-80:-5])
naoTime
# Out:
# 2011-05    1.08
# 2011-06   -1.58
# 2011-07   -3.39
# 2011-08   -2.41
# 2011-09    2.97
# 2011-10    1.31
# 2011-11    0.74
# 2011-12    3.20
# 2012-01    2.05
# 2012-02    1.28
# 2012-03    1.78
# 2012-04   -2.36
# 2012-05   -0.83
# 2012-06   -2.58
# 2012-07   -1.31
# 2012-08   -0.44
# 2012-09   -1.44
# 2012-10   -3.21
# 2012-11   -1.11
# 2012-12    0.60
# 2013-01    1.08
# 2013-02   -0.26
# 2013-03   -3.75
# 2013-04    0.03
# 2013-05    1.23
# 2013-06    1.40
# 2013-07    2.52
# 2013-08    2.16
# 2013-09   -0.57
# 2013-10   -0.36
#            ...
# 2015-02    1.47
# 2015-03    1.99
# 2015-04    1.03
# 2015-05    2.09
# 2015-06    0.28
# 2015-07   -2.16
# 2015-08    1.47
# 2015-09   -1.65
# 2015-10   -1.13
# 2015-11    3.54
# 2015-12    4.22
# 2016-01    1.17
# 2016-02    1.61
# 2016-03    0.33
# 2016-04   -2.06
# 2016-05   -0.83
# 2016-06   -1.27
# 2016-07    2.19
# 2016-08    2.14
# 2016-09    2.45
# 2016-10   -1.47
# 2016-11   -1.61
# 2016-12    2.10
# 2017-01    0.17
# 2017-02    1.38
# 2017-03    1.05
# 2017-04    1.50
# 2017-05    0.38
# 2017-06   -0.55
# 2017-07    0.10
# Freq: M, Length: 75, dtype: float64

# %%
naoAllTime.plot(figsize=(20,10),title='NAO Index')

# %% [markdown]
# ## Rainfall Data Analysis

# %%
# Download the update dataset.
import os
if not os.path.exists('../datasets/pr_1901_2015.xls'):
    ! wget http://sdwebx.worldbank.org/climateportal/DownloadData/pr_1901_2015.xls -P ../datasets/

# Import modules to read and visualize.
import pandas as pd
import numpy as np
# %pylab inline

# Read dataset. We attempt to replace three spaces with two spaces to read correctly.
from io import StringIO
columnNames=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Anual']
worldBank=pd.read_excel('../datasets/pr_1901_2015.xls',index_col=1)

worldBank.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
#               pr   Month  Country   ISO3   ISO2
# \tYear
# 1901     92.5029       1      COL    NaN    NaN
# 1901    108.6280       2      COL    NaN    NaN
# 1901    159.7820       3      COL    NaN    NaN
# 1901    204.2990       4      COL    NaN    NaN
# 1901    283.6320       5      COL    NaN    NaN

# %%
print(worldBank.columns)
worldBankMonth=worldBank.drop(columns=[' Country',' ISO3',' ISO2'])
worldBankMonth.head()
# Out:
# Index(['pr', '\tYear', ' Month', ' Country', ' ISO3', ' ISO2'], dtype='object')
#          pr  \tYear   Month
# 0   92.5029    1901       1
# 1  108.6280    1901       2
# 2  159.7820    1901       3
# 3  204.2990    1901       4
# 4  283.6320    1901       5

# %%
datesWorldBank = pd.date_range('1901-01', periods=worldBank.shape[0], freq='M')
datesWorldBank
# Out:
# DatetimeIndex(['1901-01-31', '1901-02-28', '1901-03-31', '1901-04-30',
#                '1901-05-31', '1901-06-30', '1901-07-31', '1901-08-31',
#                '1901-09-30', '1901-10-31',
#                ...
#                '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30',
#                '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31',
#                '2015-11-30', '2015-12-31'],
#               dtype='datetime64[ns]', length=1380, freq='M')

# %%
worldBankAllTime= pd.Series(np.asarray(worldBankMonth['pr']),index=datesWorldBank) 
worldBankAllTime
# Out:
# 1901-01-31     92.5029
# 1901-02-28    108.6280
# 1901-03-31    159.7820
# 1901-04-30    204.2990
# 1901-05-31    283.6320
# 1901-06-30    246.8800
# 1901-07-31    334.8780
# 1901-08-31    361.3080
# 1901-09-30    228.5250
# 1901-10-31    305.3410
# 1901-11-30    251.0160
# 1901-12-31    133.7840
# 1902-01-31    174.1600
# 1902-02-28     99.6824
# 1902-03-31    213.5380
# 1902-04-30    236.1820
# 1902-05-31    257.6330
# 1902-06-30    237.7520
# 1902-07-31    203.1070
# 1902-08-31    217.9470
# 1902-09-30    211.9500
# 1902-10-31    230.7730
# 1902-11-30    204.2130
# 1902-12-31    122.1640
# 1903-01-31    109.6790
# 1903-02-28    102.1580
# 1903-03-31    135.8310
# 1903-04-30    229.5680
# 1903-05-31    281.6720
# 1903-06-30    356.0640
#                 ...
# 2013-07-31    149.0250
# 2013-08-31    309.0680
# 2013-09-30    220.7070
# 2013-10-31    176.3320
# 2013-11-30    192.6870
# 2013-12-31    113.8580
# 2014-01-31     89.1602
# 2014-02-28    111.7820
# 2014-03-31    149.6340
# 2014-04-30    183.5800
# 2014-05-31    233.4160
# 2014-06-30    215.4540
# 2014-07-31    219.8450
# 2014-08-31    252.3560
# 2014-09-30    188.1280
# 2014-10-31    230.3030
# 2014-11-30    238.2620
# 2014-12-31    181.0480
# 2015-01-31    148.6860
# 2015-02-28    105.0790
# 2015-03-31    266.6620
# 2015-04-30    228.5930
# 2015-05-31    200.8960
# 2015-06-30    264.8430
# 2015-07-31    259.0020
# 2015-08-31    189.6000
# 2015-09-30    138.0360
# 2015-10-31    157.3480
# 2015-11-30    173.8600
# 2015-12-31     96.3039
# Freq: M, Length: 1380, dtype: float64

# %%
worldBankTime = pd.Series(worldBankAllTime.iloc[-50:])
worldBankTime
# Out:
# 2011-11-30    302.1120
# 2011-12-31    205.0320
# 2012-01-31    144.8480
# 2012-02-29     90.5267
# 2012-03-31    185.6090
# 2012-04-30    237.8860
# 2012-05-31    240.2690
# 2012-06-30    178.0720
# 2012-07-31    229.9560
# 2012-08-31    175.0850
# 2012-09-30    176.6770
# 2012-10-31    221.0640
# 2012-11-30    159.3850
# 2012-12-31    190.1550
# 2013-01-31     58.7334
# 2013-02-28    150.8400
# 2013-03-31    124.1010
# 2013-04-30    156.0180
# 2013-05-31    332.5620
# 2013-06-30    267.1480
# 2013-07-31    149.0250
# 2013-08-31    309.0680
# 2013-09-30    220.7070
# 2013-10-31    176.3320
# 2013-11-30    192.6870
# 2013-12-31    113.8580
# 2014-01-31     89.1602
# 2014-02-28    111.7820
# 2014-03-31    149.6340
# 2014-04-30    183.5800
# 2014-05-31    233.4160
# 2014-06-30    215.4540
# 2014-07-31    219.8450
# 2014-08-31    252.3560
# 2014-09-30    188.1280
# 2014-10-31    230.3030
# 2014-11-30    238.2620
# 2014-12-31    181.0480
# 2015-01-31    148.6860
# 2015-02-28    105.0790
# 2015-03-31    266.6620
# 2015-04-30    228.5930
# 2015-05-31    200.8960
# 2015-06-30    264.8430
# 2015-07-31    259.0020
# 2015-08-31    189.6000
# 2015-09-30    138.0360
# 2015-10-31    157.3480
# 2015-11-30    173.8600
# 2015-12-31     96.3039
# Freq: M, dtype: float64

# %%
worldBankTime.plot(figsize=(20,10),title='Precipitation')

# %% [markdown]
# ## Contrasting precipitation with Climate Indices

# %%
ax1=worldBankTime.plot(figsize=(20,10),label='PRE')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=1,
           ncol=2, mode="expand", borderaxespad=0.)
ax2= ax1.twinx()
ax2.spines['right'].set_position(('axes',1.0))
soiTime.plot(ax=ax2,color='green',label='SOI')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
naoTime.plot(ax=ax2,color='red',label='NAO')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
